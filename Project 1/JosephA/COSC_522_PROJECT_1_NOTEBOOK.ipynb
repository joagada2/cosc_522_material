# %% [markdown]
# # PROJECT ONE NOTEBOOK
# In line with the project requirements, synthetic datasets comprising 300 training and 150 test sets were generated for 2 classes, Class 1 and Class 2. The distribution assumed is a bivariate Gaussian distribution. These datasets were generated separately for the covariance of 0.0, 0.5, and – 0.5. The mean vectors chosen for classes 1 and 2 are [2, 4.5] and [3.5, 2.8] respectively and these mean vectors are the same for all 3 cases. For each case (of covariance 0, 0.5, and -0.5), a scatter plot was implemented for training and test sets separately. Ultimately, all the datasets were merged into a single training set, and a single test set and scatter plots were created for the combined dataset. At a covariance value of 0, the scatter plot depicts no relationship between the 2 variables. The scatter plot took a circular shape which is indicative of no correlation. At a covariance of 0.5, the scatter plot depicted an obvious positive correlation between the 2 variables. This means that the points in the scatter plots started converging around an inexistent straight line. For covariance of -0.5, the strength of the relationship as depicted by the plots remains the same but the direction changed to a negative relationship, meaning that increase in values of one variable is followed by a decrease in the values of the other variable. In the end of the entire tasks, the datasets were merged across the various cases and saved in .tr and .te file extensions.

# %% [markdown]
# # TASK ONE

# %%
# install required frameworks (No Machine Learning Framework was used in this project)
! pip install pandas numpy matplotlib

# %%
#library importation. No machine learning framework is used in this project

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import warnings
from collections import Counter
import math
# Ignore all warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## CORRELATION = 0

# %% [markdown]
# ### TRAINING SET

# %% [markdown]
# ### DISTRIBUTION 1 (W1)

# %%
# random seed for reproducibility
np.random.seed(42)

# Mean of the 2D Gaussian distribution (I chose this mean vector)
mean = [2, 4.5]

# Covariance matrix with correlation of 0
correlation = 0
covariance_matrix = [[1, correlation], [correlation, 1]]

# Generate 300 samples from the 2D Gaussian distribution
data = np.random.multivariate_normal(mean, covariance_matrix, 300)

# Extract x and y coordinates
x, y = data.T

# Create a label array with the label '1' for all points
labels_trg__1 = np.zeros(x.shape[0], dtype=int)

# Combine data and labels into a pandas DataFrame
df1_training_set_dist_1 = pd.DataFrame({'Feature1': x, 'Feature2': y, 'Label': labels_trg__1})

# Display the first few rows of the DataFrame
print(df1_training_set_dist_1.head())
# Out:
#    Feature1  Feature2  Label
# 0  2.496714  4.361736      0
# 1  2.647689  6.023030      0
# 2  1.765847  4.265863      0
# 3  3.579213  5.267435      0
# 4  1.530526  5.042560      0

# %% [markdown]
# ### DISTRIBUTION 2 (W2)

# %%
# random seed for reproducibility
np.random.seed(42)

# Mean of the 2D Gaussian distribution
mean = [3.5, 2.8]

# Covariance matrix with correlation of 0
correlation = 0
covariance_matrix = [[1, correlation], [correlation, 1]]

# Generate 300 samples from the 2D Gaussian distribution
data = np.random.multivariate_normal(mean, covariance_matrix, 300)

# Extract x and y coordinates
x, y = data.T

# Create a label array with the label '1' for all points
labels_trg_2 = np.ones(x.shape[0], dtype=int)

# Combine data and labels into a pandas DataFrame
df1_training_set_dist_2 = pd.DataFrame({'Feature1': x, 'Feature2': y, 'Label': labels_trg_2})

# Display the first few rows of the DataFrame
print(df1_training_set_dist_2.head())
# Out:
#    Feature1  Feature2  Label
# 0  3.996714  2.661736      1
# 1  4.147689  4.323030      1
# 2  3.265847  2.565863      1
# 3  5.079213  3.567435      1
# 4  3.030526  3.342560      1

# %% [markdown]
# ## TEST SET

# %% [markdown]
# ### DISTRIBUTION 1

# %%
# random seed for reproducibility
np.random.seed(42)

# Mean of the 2D Gaussian distribution
mean = [2, 4.5]

# Covariance matrix with correlation of 0
correlation = 0
covariance_matrix = [[1, correlation], [correlation, 1]]

# Generate 150 samples from the 2D Gaussian distribution
data = np.random.multivariate_normal(mean, covariance_matrix, 150)

# Extract x and y coordinates
x, y = data.T

# Create a label array with the label '1' for all points
labels_test_1 = np.zeros(x.shape[0], dtype=int)

# Combine data and labels into a pandas DataFrame
df1_test_set_dist_1 = pd.DataFrame({'Feature1': x, 'Feature2': y, 'Label': labels_test_1})

# Display the first few rows of the DataFrame
print(df1_test_set_dist_1.head())
# Out:
#    Feature1  Feature2  Label
# 0  2.496714  4.361736      0
# 1  2.647689  6.023030      0
# 2  1.765847  4.265863      0
# 3  3.579213  5.267435      0
# 4  1.530526  5.042560      0

# %% [markdown]
# ### DISTRIBUTION 2

# %%
# random seed for reproducibility
np.random.seed(42)

# Mean of the 2D Gaussian distribution
mean = [3.5, 2.8]

# Covariance matrix with correlation of 0
correlation = 0
covariance_matrix = [[1, correlation], [correlation, 1]]

# Generate 150 samples from the 2D Gaussian distribution
data = np.random.multivariate_normal(mean, covariance_matrix, 150)

# Extract x and y coordinates
x, y = data.T

# Create a label array with the label '1' for all points
labels_test_2 = np.ones(x.shape[0], dtype=int)

# Combine data and labels into a pandas DataFrame
df1_test_set_dist_2 = pd.DataFrame({'Feature1': x, 'Feature2': y, 'Label': labels_test_2})

# Display the first few rows of the DataFrame
print(df1_test_set_dist_2.head())
# Out:
#    Feature1  Feature2  Label
# 0  3.996714  2.661736      1
# 1  4.147689  4.323030      1
# 2  3.265847  2.565863      1
# 3  5.079213  3.567435      1
# 4  3.030526  3.342560      1

# %% [markdown]
# ### SCATTER PLOT FOR CORRELATION = 0

# %% [markdown]
# #### SCATTER PLOT FOR TRAINING SET

# %%
# Concatenate the various datasets for covariance = 0
df_1_training = pd.concat([df1_training_set_dist_1, df1_training_set_dist_2], ignore_index=True)
# Plot the generated data with labels
plt.scatter(df_1_training['Feature1'], df_1_training['Feature2'], c=df_1_training['Label'], cmap='viridis', alpha=0.5)
plt.title('2D Gaussian Distribution with Correlation 0.2 (Label 1)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# #### SCATTER PLOT FOR TEST SET

# %%
# Concatenate the various datasets for covariance = 0
df_1_test = pd.concat([df1_test_set_dist_1,df1_test_set_dist_2], ignore_index=True)
# Plot the generated data with labels
plt.scatter(df_1_test['Feature1'], df_1_test['Feature2'], c=df_1_test['Label'], cmap='viridis', alpha=0.5)
plt.title('2D Gaussian Distribution with Correlation 0.2 (Label 1)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ## CORRELATION = 0.5

# %% [markdown]
# ### TRAINING SET

# %% [markdown]
# ### DISTRIBUTION 1 (W1)

# %%
# random seed for reproducibility
np.random.seed(42)

# Mean of the 2D Gaussian distribution
mean = [2, 4.5]

# Covariance matrix with correlation of 0.5
correlation = 0.5
covariance_matrix = [[1, correlation], [correlation, 1]]

# Generate 300 samples from the 2D Gaussian distribution
data = np.random.multivariate_normal(mean, covariance_matrix, 300)

# Extract x and y coordinates
x, y = data.T

# Create a label array with the label '1' for all points
labels_trg__1 = np.zeros(x.shape[0], dtype=int)

# Combine data and labels into a pandas DataFrame
df2_training_set_dist_1 = pd.DataFrame({'Feature1': x, 'Feature2': y, 'Label': labels_trg__1})

# Display the first few rows of the DataFrame
print(df2_training_set_dist_1.head())
# Out:
#    Feature1  Feature2  Label
# 0  1.638965  4.000701      0
# 1  0.677570  4.700600      0
# 2  2.319851  4.585714      0
# 3  0.248644  3.516079      0
# 4  2.135297  5.177857      0

# %% [markdown]
# ### DISTRIBUTION 2 (W2)

# %%
#  random seed for reproducibility
np.random.seed(42)

# Mean of the 2D Gaussian distribution
mean = [3.5, 2.8]

# Covariance matrix with correlation of 0.5
correlation = 0.5
covariance_matrix = [[1, correlation], [correlation, 1]]

# Generate 300 samples from the 2D Gaussian distribution
data = np.random.multivariate_normal(mean, covariance_matrix, 300)

# Extract x and y coordinates
x, y = data.T

# Create a label array with the label '1' for all points
labels_trg_2 = np.ones(x.shape[0], dtype=int)

# Combine data and labels into a pandas DataFrame
df2_training_set_dist_2 = pd.DataFrame({'Feature1': x, 'Feature2': y, 'Label': labels_trg_2})

# Display the first few rows of the DataFrame
print(df2_training_set_dist_2.head())
# Out:
#    Feature1  Feature2  Label
# 0  3.138965  2.300701      1
# 1  2.177570  3.000600      1
# 2  3.819851  2.885714      1
# 3  1.748644  1.816079      1
# 4  3.635297  3.477857      1

# %% [markdown]
# ## TEST SET

# %% [markdown]
# ### DISTRIBUTION 1

# %%
# random seed for reproducibility
np.random.seed(42)

# Mean of the 2D Gaussian distribution
mean = [2, 4.5]

# Covariance matrix with correlation of 0.5
correlation = 0.5
covariance_matrix = [[1, correlation], [correlation, 1]]

# Generate 150 samples from the 2D Gaussian distribution
data = np.random.multivariate_normal(mean, covariance_matrix, 150)

# Extract x and y coordinates
x, y = data.T

# Create a label array with the label '1' for all points
labels_test_1 = np.zeros(x.shape[0], dtype=int)

# Combine data and labels into a pandas DataFrame
df2_test_set_dist_1 = pd.DataFrame({'Feature1': x, 'Feature2': y, 'Label': labels_test_1})

# Display the first few rows of the DataFrame
print(df2_test_set_dist_1.head())
# Out:
#    Feature1  Feature2  Label
# 0  1.638965  4.000701      0
# 1  0.677570  4.700600      0
# 2  2.319851  4.585714      0
# 3  0.248644  3.516079      0
# 4  2.135297  5.177857      0

# %% [markdown]
# ### DISTRIBUTION 2

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Mean of the 2D Gaussian distribution
mean = [3.5, 2.8]

# Covariance matrix with correlation of 0.5
correlation = 0.5
covariance_matrix = [[1, correlation], [correlation, 1]]

# Generate 150 samples from the 2D Gaussian distribution
data = np.random.multivariate_normal(mean, covariance_matrix, 150)

# Extract x and y coordinates
x, y = data.T

# Create a label array with the label '1' for all points
labels_test_2 = np.ones(x.shape[0], dtype=int)

# Combine data and labels into a pandas DataFrame
df2_test_set_dist_2 = pd.DataFrame({'Feature1': x, 'Feature2': y, 'Label': labels_test_2})

# Display the first few rows of the DataFrame
print(df2_test_set_dist_2.head())
# Out:
#    Feature1  Feature2  Label
# 0  3.138965  2.300701      1
# 1  2.177570  3.000600      1
# 2  3.819851  2.885714      1
# 3  1.748644  1.816079      1
# 4  3.635297  3.477857      1

# %% [markdown]
# ## SCATTER PLOT FOR CORRELATION = 0.5

# %% [markdown]
# ### SCATTER PLOT FOR TRAINING SET

# %%
# Concatenate the various datasets for covariance = 0.2
df_2_training = pd.concat([df2_training_set_dist_1, df2_training_set_dist_2,], ignore_index=True)
# Plot the generated data with labels
plt.scatter(df_2_training['Feature1'], df_2_training['Feature2'], c=df_2_training['Label'], cmap='viridis', alpha=0.5)
plt.title('2D Gaussian Distribution with Correlation 0.5 (Label 1)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ### SCATTER PLOT FOR TEST SET

# %%
# Concatenate the various datasets for covariance = 0.5
df_2_test = pd.concat([df2_test_set_dist_1,df2_test_set_dist_2], ignore_index=True)
# Plot the generated data with labels
plt.scatter(df_2_test['Feature1'], df_2_test['Feature2'], c=df_2_test['Label'], cmap='viridis', alpha=0.5)
plt.title('2D Gaussian Distribution with Correlation 0.5 (Label 1)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ## CORRELATION = -0.5

# %% [markdown]
# ### TRAINING SET

# %% [markdown]
# ### DISTRIBUTION 1 (W1)

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Mean of the 2D Gaussian distribution
mean = [2, 4.5]

# Covariance matrix with correlation of -0.5
correlation = -0.5
covariance_matrix = [[1, correlation], [correlation, 1]]

# Generate 300 samples from the 2D Gaussian distribution
data = np.random.multivariate_normal(mean, covariance_matrix, 300)

# Extract x and y coordinates
x, y = data.T

# Create a label array with the label '1' for all points
labels_trg__1 = np.zeros(x.shape[0], dtype=int)

# Combine data and labels into a pandas DataFrame
df3_training_set_dist_1 = pd.DataFrame({'Feature1': x, 'Feature2': y, 'Label': labels_trg__1})

# Display the first few rows of the DataFrame
print(df3_training_set_dist_1.head())
# Out:
#    Feature1  Feature2  Label
# 0  1.500701  4.861035      0
# 1  2.200600  5.822430      0
# 2  2.085714  4.180149      0
# 3  1.016079  6.251356      0
# 4  2.677857  4.364703      0

# %% [markdown]
# ### DISTRIBUTION 2 (W2)

# %%
# random seed for reproducibility
np.random.seed(42)

# Mean of the 2D Gaussian distribution
mean = [3.5, 2.8]

# Covariance matrix with correlation of -0.5
correlation = -0.5
covariance_matrix = [[1, correlation], [correlation, 1]]

# Generate 300 samples from the 2D Gaussian distribution
data = np.random.multivariate_normal(mean, covariance_matrix, 300)

# Extract x and y coordinates
x, y = data.T

# Create a label array with the label '1' for all points
labels_trg_2 = np.ones(x.shape[0], dtype=int)

# Combine data and labels into a pandas DataFrame
df3_training_set_dist_2 = pd.DataFrame({'Feature1': x, 'Feature2': y, 'Label': labels_trg_2})

# Display the first few rows of the DataFrame
print(df3_training_set_dist_2.head())
# Out:
#    Feature1  Feature2  Label
# 0  3.000701  3.161035      1
# 1  3.700600  4.122430      1
# 2  3.585714  2.480149      1
# 3  2.516079  4.551356      1
# 4  4.177857  2.664703      1

# %% [markdown]
# ## TEST SET

# %% [markdown]
# ### DISTRIBUTION 1 (W1)

# %%
# random seed for reproducibility
np.random.seed(42)

# Mean of the 2D Gaussian distribution
mean = [2, 4.5]

# Covariance matrix with correlation of -0.5
correlation = -0.5
covariance_matrix = [[1, correlation], [correlation, 1]]

# Generate 150 samples from the 2D Gaussian distribution
data = np.random.multivariate_normal(mean, covariance_matrix, 150)

# Extract x and y coordinates
x, y = data.T

# Create a label array with the label '1' for all points
labels_test_1 = np.zeros(x.shape[0], dtype=int)

# Combine data and labels into a pandas DataFrame
df3_test_set_dist_1 = pd.DataFrame({'Feature1': x, 'Feature2': y, 'Label': labels_test_1})

# Display the first few rows of the DataFrame
print(df3_test_set_dist_1.head())
# Out:
#    Feature1  Feature2  Label
# 0  1.500701  4.861035      0
# 1  2.200600  5.822430      0
# 2  2.085714  4.180149      0
# 3  1.016079  6.251356      0
# 4  2.677857  4.364703      0

# %% [markdown]
# ### DISTRIBUTION 2 (W2)

# %%
# random seed for reproducibility
np.random.seed(42)

# Mean of the 2D Gaussian distribution
mean = [3.5, 2.8]

# Covariance matrix with correlation of -0.5
correlation = -0.5
covariance_matrix = [[1, correlation], [correlation, 1]]

# Generate 150 samples from the 2D Gaussian distribution
data = np.random.multivariate_normal(mean, covariance_matrix, 150)

# Extract x and y coordinates
x, y = data.T

# Create a label array with the label '1' for all points
labels_test_2 = np.ones(x.shape[0], dtype=int)

# Combine data and labels into a pandas DataFrame
df3_test_set_dist_2 = pd.DataFrame({'Feature1': x, 'Feature2': y, 'Label': labels_test_2})

# Display the first few rows of the DataFrame
print(df3_test_set_dist_2.head())
# Out:
#    Feature1  Feature2  Label
# 0  3.000701  3.161035      1
# 1  3.700600  4.122430      1
# 2  3.585714  2.480149      1
# 3  2.516079  4.551356      1
# 4  4.177857  2.664703      1

# %% [markdown]
# ## SCATTER PLOT FOR CORRELATION = -0.05

# %% [markdown]
# ### SCATTER PLOT FOR TRAINING SET

# %%
# Concatenate the various datasets for covariance = 0.2
df_3_training = pd.concat([df3_training_set_dist_1, df3_training_set_dist_2], ignore_index=True)
# Plot the generated data with labels
plt.scatter(df_3_training['Feature1'], df_3_training['Feature2'], c=df_3_training['Label'], cmap='viridis', alpha=0.5)
plt.title('2D Gaussian Distribution with Correlation -0.5 (Label 1)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ### SCATTER PLOT FOR TEST SET

# %%
# Concatenate the various datasets for covariance = 0.2
df_3_test = pd.concat([df3_test_set_dist_1,df3_test_set_dist_2], ignore_index=True)
# Plot the generated data with labels
plt.scatter(df_3_test['Feature1'], df_3_test['Feature2'], c=df_3_test['Label'], cmap='viridis', alpha=0.5)
plt.title('2D Gaussian Distribution with Correlation -0.5 (Label 1)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ## PLOT FOR ALL DISTRIBUTION COMBINED

# %% [markdown]
# ### PLOT FOR TRAINING SET

# %%
# Plot the generated data with labels
plt.scatter(df_1_training['Feature1'], df_1_training['Feature2'], c=df_1_training['Label'], cmap='viridis', alpha=0.5)
plt.scatter(df_2_training['Feature1'], df_2_training['Feature2'], c=df_2_training['Label'], cmap='cividis', alpha=0.5)
plt.scatter(df_3_training['Feature1'], df_3_training['Feature2'], c=df_3_training['Label'], cmap='seismic', alpha=0.5)
plt.title('2D Gaussian Distribution with Correlation for Training Set')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# ### PLOT FOR TEST SET

# %%
# Plot the generated data with labels
plt.scatter(df_1_test['Feature1'], df_1_test['Feature2'], c=df_1_test['Label'], cmap='viridis', alpha=0.5)
plt.scatter(df_2_test['Feature1'], df_2_test['Feature2'], c=df_2_test['Label'], cmap='cividis', alpha=0.5)
plt.scatter(df_3_test['Feature1'], df_3_test['Feature2'], c=df_3_test['Label'], cmap='seismic', alpha=0.5)
plt.title('2D Gaussian Distribution with Correlation for Test Set')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# # TASK TWO
# ### Implementing KNN Without Using Any Python Framework using Euclidean Distance as Preferred Distance Measure
# In Task 2, I implemented KNN classification on the dataset (without using any machine learning framework) for k running from 1 to 50. Thereafter, I plotted k values against accuracy and realized that accuracy generally decreased with an increase in the value of k.

# %%
# concatenate the previously generated dataset into a training set and a test set
df_training = pd.concat([df_1_training, df_2_training, df_3_training], ignore_index=True)
df_test = pd.concat([df_1_test, df_2_test, df_3_test], ignore_index=True)

# %%
# Split data into training and testing sets without using the tran_test_split module of Sklearn
X_train = df_training[['Feature1', 'Feature2']].values
y_train = df_training['Label'].values

X_test = df_test[['Feature1', 'Feature2']].values
y_test = df_test['Label'].values

# Function to calculate Euclidean distance
def euclidean_distance(x1, x2):
    return np.sqrt(np.sum((x1 - x2) ** 2))

# KNN function without using any frameworks
def knn_predict(X_train, y_train, X_test, k):
    predictions = []
    for test_point in X_test:
        # Calculate distances from the test point to all training points
        distances = [euclidean_distance(test_point, x) for x in X_train]
        # Get the indices of the k nearest neighbors
        k_indices = np.argsort(distances)[:k]
        # Get the labels of the k nearest neighbors
        k_nearest_labels = [y_train[i] for i in k_indices]
        # Determine the most common label
        most_common = Counter(k_nearest_labels).most_common(1)
        predictions.append(most_common[0][0])
    return np.array(predictions)

# Function to calculate accuracy
def calculate_accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / len(y_true)

# Testing different values of k
k_values = range(1, 50)
accuracies = []

for k in k_values:
    y_pred = knn_predict(X_train, y_train, X_test, k)
    accuracy = calculate_accuracy(y_test, y_pred)
    accuracies.append(accuracy)
    print(f"Accuracy for k={k}: {accuracy:.2f}")

# Plotting k values against their accuracies
plt.figure(figsize=(10, 6))
plt.plot(k_values, accuracies, marker='o', linestyle='-')
plt.title('KNN Accuracy vs. k Value')
plt.xlabel('k Value')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
# Out:
# Accuracy for k=1: 1.00
# Accuracy for k=2: 1.00
# Accuracy for k=3: 0.93
# Accuracy for k=4: 0.95
# Accuracy for k=5: 0.91
# Accuracy for k=6: 0.93
# Accuracy for k=7: 0.91
# Accuracy for k=8: 0.91
# Accuracy for k=9: 0.91
# Accuracy for k=10: 0.92
# Accuracy for k=11: 0.90
# Accuracy for k=12: 0.91
# Accuracy for k=13: 0.90
# Accuracy for k=14: 0.90
# Accuracy for k=15: 0.89
# Accuracy for k=16: 0.90
# Accuracy for k=17: 0.89
# Accuracy for k=18: 0.90
# Accuracy for k=19: 0.89
# Accuracy for k=20: 0.89
# Accuracy for k=21: 0.89
# Accuracy for k=22: 0.90
# Accuracy for k=23: 0.90
# Accuracy for k=24: 0.90
# Accuracy for k=25: 0.89
# Accuracy for k=26: 0.90
# Accuracy for k=27: 0.90
# Accuracy for k=28: 0.90
# Accuracy for k=29: 0.89
# Accuracy for k=30: 0.90
# Accuracy for k=31: 0.89
# Accuracy for k=32: 0.90
# Accuracy for k=33: 0.89
# Accuracy for k=34: 0.89
# Accuracy for k=35: 0.89
# Accuracy for k=36: 0.90
# Accuracy for k=37: 0.89
# Accuracy for k=38: 0.89
# ...

# %% [markdown]
# # TASK THREE
# In Task 3, I implemented the KNN Classifier, Quadratic Discriminant Classifier, Mahalanobis Distance Classifier, and Euclidean Distance Classifier. I also went ahead to calculate overall accuracy, class-wise accuracy, and run time for each of the models. Prior probabilities here are equal because the dataset used is perfectly balanced, meaning that both class 1 and class 2 have the same number of samples.

# %%
# Set random seed for reproducibility
np.random.seed(42)

# KNN Classifier Implementation with k=3
def knn_classifier(X_train, y_train, X_test, k=3):
    predictions = []
    for x in X_test:
        # Calculate Euclidean distances to all training samples
        distances = np.linalg.norm(X_train - x, axis=1)
        # Get the indices of the k nearest neighbors
        k_indices = np.argsort(distances)[:k]
        # Predict the class with the majority vote
        k_nearest_labels = y_train[k_indices]
        prediction = np.argmax(np.bincount(k_nearest_labels.astype(int)))
        predictions.append(prediction)
    return np.array(predictions)

# Quadratic Discriminant Classifier Implementation
def qda_classifier(X_train, y_train, X_test):
    mean_1 = np.mean(X_train[y_train == 1], axis=0)
    mean_2 = np.mean(X_train[y_train == 0], axis=0)
    cov_1 = np.cov(X_train[y_train == 1], rowvar=False)
    cov_2 = np.cov(X_train[y_train == 0], rowvar=False)
    predictions = []
    for x in X_test:
        # Compute discriminant function for both classes
        g1 = -0.5 * np.dot(np.dot((x - mean_1), np.linalg.inv(cov_1)), (x - mean_1).T) - 0.5 * np.log(np.linalg.det(cov_1))
        g2 = -0.5 * np.dot(np.dot((x - mean_2), np.linalg.inv(cov_2)), (x - mean_2).T) - 0.5 * np.log(np.linalg.det(cov_2))
        predictions.append(1 if g1 > g2 else 0)
    return np.array(predictions)

# Mahalanobis Distance Classifier Implementation
def mahalanobis_classifier(X_train, y_train, X_test):
    mean_1 = np.mean(X_train[y_train == 1], axis=0)
    mean_2 = np.mean(X_train[y_train == 0], axis=0)
    cov = np.cov(X_train, rowvar=False)
    inv_cov = np.linalg.inv(cov)
    predictions = []
    for x in X_test:
        dist_to_1 = np.sqrt(np.dot(np.dot((x - mean_1), inv_cov), (x - mean_1).T))
        dist_to_2 = np.sqrt(np.dot(np.dot((x - mean_2), inv_cov), (x - mean_2).T))
        predictions.append(1 if dist_to_1 < dist_to_2 else 0)
    return np.array(predictions)

# Euclidean Distance Classifier Implementation
def euclidean_classifier(X_train, y_train, X_test):
    mean_1 = np.mean(X_train[y_train == 1], axis=0)
    mean_2 = np.mean(X_train[y_train == 0], axis=0)
    predictions = []
    for x in X_test:
        dist_to_1 = np.linalg.norm(x - mean_1)
        dist_to_2 = np.linalg.norm(x - mean_2)
        predictions.append(1 if dist_to_1 < dist_to_2 else 0)
    return np.array(predictions)

# Function to calculate accuracy and classwise accuracy
def calculate_accuracy(y_true, y_pred):
    overall_accuracy = np.mean(y_true == y_pred)
    class_1_accuracy = np.mean(y_pred[y_true == 1] == 1)
    class_2_accuracy = np.mean(y_pred[y_true == 0] == 0)
    return overall_accuracy, class_1_accuracy, class_2_accuracy

# Collecting results for all classifiers
results = []

# KNN Classifier
start_time = time.time()
y_pred_knn = knn_classifier(X_train, y_train, X_test, k=3)
knn_overall, knn_class1, knn_class2 = calculate_accuracy(y_test, y_pred_knn)
knn_time = time.time() - start_time
results.append(['KNN', knn_overall, knn_class1, knn_class2, knn_time])

# QDA Classifier
start_time = time.time()
y_pred_qda = qda_classifier(X_train, y_train, X_test)
qda_overall, qda_class1, qda_class2 = calculate_accuracy(y_test, y_pred_qda)
qda_time = time.time() - start_time
results.append(['QDA', qda_overall, qda_class1, qda_class2, qda_time])

# Mahalanobis Distance Classifier
start_time = time.time()
y_pred_mahalanobis = mahalanobis_classifier(X_train, y_train, X_test)
maha_overall, maha_class1, maha_class2 = calculate_accuracy(y_test, y_pred_mahalanobis)
maha_time = time.time() - start_time
results.append(['Mahalanobis', maha_overall, maha_class1, maha_class2, maha_time])

# Euclidean Distance Classifier
start_time = time.time()
y_pred_euclidean = euclidean_classifier(X_train, y_train, X_test)
euclidean_overall, euclidean_class1, euclidean_class2 = calculate_accuracy(y_test, y_pred_euclidean)
euclidean_time = time.time() - start_time
results.append(['Euclidean', euclidean_overall, euclidean_class1, euclidean_class2, euclidean_time])

# Printing results in tabular format
print("Summary of Classification Performance:")
print(f"{'Classifier':<15}{'Overall Accuracy':<20}{'Class 1 Accuracy':<20}{'Class 2 Accuracy':<20}{'Run Time (s)':<10}")
for row in results:
    print(f"{row[0]:<15}{row[1]:<20.4f}{row[2]:<20.4f}{row[3]:<20.4f}{row[4]:<10.4f}")
# Out:
# Summary of Classification Performance:
# Classifier     Overall Accuracy    Class 1 Accuracy    Class 2 Accuracy    Run Time (s)
# KNN            0.9289              0.9244              0.9333              0.2849
# QDA            0.8944              0.8978              0.8911              0.0873
# Mahalanobis    0.8944              0.8978              0.8911              0.0329
# Euclidean      0.8944              0.8978              0.8911              0.0219

# %% [markdown]
# # TASK FOUR
# The four classification algorithms used, all performed well. However, KNN has the highest performance but at the expense of computational complexity, being that the runtime of 0.2849 sec was the highest among all the classifiers. In terms of the assumption of equality or non-equality of covariance, the reality is the covariance for the two classes is equal but not identical. This agrees with the assumption of the Mahalonobis distance classifier. However, the Mahalanobis distance classifier has the same performance as the Quadratic Discriminant Classifier and Euclidean Distance Classifier. Therefore, violation of the assumption of the difference covariance matrix for the Quadratic Discriminant Classifier and that of the equal and identical covariance matrix for the Euclidean Distance Classifier did not impact the performance of these classification algorithms. Therefore, it is safe to say that Quadratic Discriminant and Euclidean Distance Classifiers can always be used even if their assumptions about covariance matrices are violated.

# %% [markdown]
# # TASK 5
# The decision boundary is superimposed on the scatter plot for the various classification algorithms. As seen in the plot below, the decision boundaries for KNN and QDA are non-linear while those of Mahalanobis Distance and Euclidean Distance classifiers are linear. The behavior of the decision boundaries is in line with expectations based on the theoretical standpoint.

# %%
# Visualization of decision boundaries
def plot_decision_boundaries(X_test, y_test, classifier_func, title):
    # Plotting the decision boundary using meshgrid
    x_min, x_max = min(x[0] for x in X_test) - 1, max(x[0] for x in X_train) + 1
    y_min, y_max = min(x[1] for x in X_test) - 1, max(x[1] for x in X_train) + 1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))
    Z = np.array([classifier_func(X_train, y_train, [[xi, yi]])[0] for xi, yi in zip(np.ravel(xx), np.ravel(yy))])
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, alpha=0.3)
    plt.scatter(*zip(*X_train), c=y_train, edgecolor='k', s=50)
    plt.title(title)

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plot_decision_boundaries(X_test, y_test, knn_classifier, "k-NN (k=20)")

plt.subplot(2, 2, 2)
plot_decision_boundaries(X_test, y_test, euclidean_classifier, "Euclidean Classifier")

plt.subplot(2, 2, 3)
plot_decision_boundaries(X_test, y_test, mahalanobis_classifier, "Mahalanobis Classifier")

plt.subplot(2, 2, 4)
plot_decision_boundaries(X_test, y_test, qda_classifier, "QDA Classifier")

plt.tight_layout()
plt.show()

# %% [markdown]
# # BONUS TASK ONE
# As seen in the plot below, prior probabilities have a significant impact on the performance of the minimum Euclidean Distance Classifier. The closer the probability of class 1 is to 0.5, the better the performance of the model. The model has its best performance at the probability of class 1 ranging from 0.44 to 0.65.

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Parameters for Gaussian distributions
mean_w1 = [2, 2]           # Mean for class 1
cov_w1 = [[1, 0.5], [0.5, 1]]   # Covariance matrix for class 1

mean_w2 = [-2, -2]         # Mean for class 2
cov_w2 = [[1, -0.5], [-0.5, 1]] # Covariance matrix for class 2

# Generating training set: 300 samples from class 1, 100 samples from class 2
X_train_w1 = np.random.multivariate_normal(mean_w1, cov_w1, 300)
y_train_w1 = np.ones(300)  # Label for class 1

X_train_w2 = np.random.multivariate_normal(mean_w2, cov_w2, 100)
y_train_w2 = np.zeros(100) # Label for class 2

X_train = np.vstack((X_train_w1, X_train_w2))
y_train = np.hstack((y_train_w1, y_train_w2))

# Generating testing set: 150 samples from class 1, 30 samples from class 2
X_test_w1 = np.random.multivariate_normal(mean_w1, cov_w1, 150)
y_test_w1 = np.ones(150)   # Label for class 1

X_test_w2 = np.random.multivariate_normal(mean_w2, cov_w2, 30)
y_test_w2 = np.zeros(30)   # Label for class 2

X_test = np.vstack((X_test_w1, X_test_w2))
y_test = np.hstack((y_test_w1, y_test_w2))

# Minimum Euclidean distance classifier
def euclidean_distance_classifier(X_train, y_train, X_test, prior_w1):
    # Compute class means
    mean_class_1 = np.mean(X_train[y_train == 1], axis=0)
    mean_class_2 = np.mean(X_train[y_train == 0], axis=0)

    # Classify each point in the test set
    predictions = []
    for x in X_test:
        # Calculate distances to class means
        dist_to_w1 = np.linalg.norm(x - mean_class_1)
        dist_to_w2 = np.linalg.norm(x - mean_class_2)
        
        # Bayesian decision rule considering priors
        if dist_to_w1 * (1 / prior_w1) < dist_to_w2 * (1 / (1 - prior_w1)):
            predictions.append(1)  # Classify as class 1
        else:
            predictions.append(0)  # Classify as class 2
            
    return np.array(predictions)

# Calculate classification accuracy for varying prior probabilities of P(w1)
priors = np.linspace(0.01, 0.99, 100)  # Avoid extreme cases of 0 and 1
accuracies = []

for prior_w1 in priors:
    y_pred = euclidean_distance_classifier(X_train, y_train, X_test, prior_w1)
    accuracy = np.mean(y_pred == y_test)  # Calculate accuracy
    accuracies.append(accuracy)

# Plotting the classification accuracy vs. P(w1)
plt.figure(figsize=(10, 6))
plt.plot(priors, accuracies, marker='o', color='b')
plt.title("Classification Accuracy vs. P(w1)")
plt.xlabel("P(w1)")
plt.ylabel("Overall Classification Accuracy")
plt.grid(True)
plt.show()

# %% [markdown]
# ## SAVING THE SAMPLE/SYNTHETIC DATA AS .tr and .te files

# %%
# Combining all the dataset
df = pd.concat([df_1_training, df_2_training, df_3_training, df_1_test, df_2_test, df_3_test,], ignore_index=True)

# %%
df.shape

# %%
# Saving the dataset in .tr format
df.to_csv('synth.tr', sep='\t', index=False)

# %%
# Saving the dataset in .te format
df.to_csv('synth.te', sep='\t', index=False)

# %%
import GPUtil
   
if GPUtil.getAvailable():
    print("GPU is available!")
else:
    print("No GPU available.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import GPUtil
#       3 if GPUtil.getAvailable():
#       4     print("GPU is available!")
#
# ModuleNotFoundError: No module named 'GPUtil'
